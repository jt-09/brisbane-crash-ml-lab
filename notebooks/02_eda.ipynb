# %% [markdown]
# # 02 — Exploratory analysis
#
# Calls reproducible EDA generators in `crashlab.evaluation.eda`.

# %%
from crashlab.config import load_config
from crashlab.evaluation.eda import run_eda
from crashlab.paths import ensure_dirs

config = load_config("smoke")
paths = ensure_dirs(config)
run_eda(config, paths)
